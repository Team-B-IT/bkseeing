# %% [markdown]
# Kết nối với Drive

# %%
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Test

# %%
import os
for file_name in os.listdir("./drive/My Drive"):
  print(file_name)

# %% [markdown]
# Thay đổi thư mục gốc

# %%
# %cd "drive/My Drive/bkseeing/"
# Out:
# /content/drive/My Drive/bkseeing

# %%
# %cd ..

# %%
# !ls
# Out:
# 'Android App'  'Data tools'   fpga   README.md	 setup	 yolov3_keras

# %%
# !git config --global user.email "vuong.1998@gmail.com"
# !git config --global user.name "Đặng Xuân Vương"

# %%
# !git pull

# %%
# !git add .

# %%
# !git commit -m "from google drive"
# !git push

# %%
import os
files = os.listdir()
with open("../../train.txt", "w") as f:
  for file in files:
    f.write("dataver1/data-des/" + file + '\n')
    print("dataver1/data-des/" + file)

# %% [markdown]
# 1. Download YOLOv3 weights from [YOLO website](http://pjreddie.com/darknet/yolo/).
# 2. Convert the Darknet YOLO model to a Keras model.
# 3. Run YOLO detection.

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights

# %%
# !python convert.py yolov3.cfg yolov3.weights model_data/yolo.h5

# %%
# !python yolo_video.py --image
